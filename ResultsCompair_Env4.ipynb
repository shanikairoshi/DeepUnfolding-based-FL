# %% [markdown]
# <a href="https://colab.research.google.com/github/shanikairoshi/DeepUnfolding-based-FL/blob/main/ResultsCompair_Env4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print(fl_acc)#duw
print(fl2_acc)#FedAvg
print(fl3_acc)#dr
# Out:
# [0.1616, 0.4473, 0.6124, 0.6749, 0.7267, 0.7532, 0.795, 0.8229, 0.8284, 0.8368]
# [0.1636, 0.3853, 0.5875, 0.6714, 0.7201, 0.7505, 0.7908, 0.8107, 0.8093, 0.8208]
# [0.1757, 0.396, 0.6166, 0.6709, 0.7208, 0.7348, 0.7757, 0.807, 0.8125, 0.8235]

# %% [markdown]
# Read Results and draw graphs

# %%
#code for environment 01
import matplotlib.pyplot as plt
import csv
import seaborn as sns
# Define the file path
filename = "defaultresultsEnv4_FedAvg.csv"

sns.set_style("darkgrid")

# Create empty lists to store the data
iterations = []
Default_FedAvgloss = []
Default_FedAvgacc = []

# Read the CSV file
with open(filename, 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        iterations.append(int(row['Iteration']))
        Default_FedAvgloss.append(float(row['Loss']))
        Default_FedAvgacc.append(float(row['Accuracy']))

# Print the retrieved data
#print("Iterations:", iterations)
print("FedAvgloss Losses:", Default_FedAvgloss)
print("FedAvgacc Accuracies:", Default_FedAvgacc)
#==================================

# Define the file path
filename = "defaultresultsEnv4_DR.csv"

# Create empty lists to store the data
iterations = []
DR_loss = []
DR_acc = []

# Read the CSV file
with open(filename, 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        iterations.append(int(row['Iteration']))
        DR_loss.append(float(row['Loss']))
        DR_acc.append(float(row['Accuracy']))

# Print the retrieved data
#print("Iterations:", iterations)
print("DR_loss Losses:", DR_loss)
print("DR_acc Accuracies:", DR_acc)

#================================================
# Define the file path
filename = "defaultresultsEnv4_DUW.csv"

# Create empty lists to store the data
iterations = []
Default_DUW_loss = []
Default_DUW_acc = []

# Read the CSV file
with open(filename, 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        iterations.append(int(row['Iteration']))
        Default_DUW_loss.append(float(row['Loss']))
        Default_DUW_acc.append(float(row['Accuracy']))

# Print the retrieved data
#print("Iterations:", iterations)
print("Default_DUW_loss Losses:", Default_DUW_loss)
print("Default_DUW_acc Accuracies:", Default_DUW_acc)

# Define the file path
filename = "FLAdamwithWeightDecay_DeepUnfolding_Code_Env4.csv"

# Create empty lists to store the data
iterations = []
FLAdamwithWeightDecay_DeepUnfolding_Code_Env4_loss = []
FLAdamwithWeightDecay_DeepUnfolding_Code_Env4_acc = []

# Read the CSV file
with open(filename, 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        iterations.append(int(row['Iteration']))
        FLAdamwithWeightDecay_DeepUnfolding_Code_Env4_loss.append(float(row['Loss']))
        FLAdamwithWeightDecay_DeepUnfolding_Code_Env4_acc.append(float(row['Accuracy']))

# Print the retrieved data
#print("Iterations:", iterations)
print("FLAdamwithWeightDecay_DeepUnfolding_Code_Env4_loss Losses:", FLAdamwithWeightDecay_DeepUnfolding_Code_Env4_loss)
print("FLAdamwithWeightDecay_DeepUnfolding_Code_Env4_acc Accuracies:", FLAdamwithWeightDecay_DeepUnfolding_Code_Env4_acc)

#============================
# Define the file path
filename = "FLSGDwithWeightDecay_DeepUnfolding_Code_Env4.csv"

# Create empty lists to store the data
iterations = []
FLSGDwithWeightDecay_DeepUnfolding_Code_Env4_loss = []
FLSGDwithWeightDecay_DeepUnfolding_Code_Env4_acc = []

# Read the CSV file
with open(filename, 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        iterations.append(int(row['Iteration']))
        FLSGDwithWeightDecay_DeepUnfolding_Code_Env4_loss.append(float(row['Loss']))
        FLSGDwithWeightDecay_DeepUnfolding_Code_Env4_acc.append(float(row['Accuracy']))

# Print the retrieved data
#print("Iterations:", iterations)
print("FLSGDwithWeightDecay_DeepUnfolding_Code_Env4_loss Losses:", FLSGDwithWeightDecay_DeepUnfolding_Code_Env4_loss)
print("FLSGDwithWeightDecay_DeepUnfolding_Code_Env4_acc Accuracies:", FLSGDwithWeightDecay_DeepUnfolding_Code_Env4_acc)

#======================================

# Define the file path
filename = "WeightDecay_onlyfor_DeepUnfolding_Code_Env4.csv"

# Create empty lists to store the data
iterations = []
WeightDecay_onlyfor_DeepUnfolding_Code_Env4_loss = []
WeightDecay_onlyfor_DeepUnfolding_Code_Env4_acc = []

# Read the CSV file
with open(filename, 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        iterations.append(int(row['Iteration']))
        WeightDecay_onlyfor_DeepUnfolding_Code_Env4_loss.append(float(row['Loss']))
        WeightDecay_onlyfor_DeepUnfolding_Code_Env4_acc.append(float(row['Accuracy']))

# Print the retrieved data
#print("Iterations:", iterations)
print("WeightDecay_onlyfor_DeepUnfolding_Code_Env4_loss Losses:", WeightDecay_onlyfor_DeepUnfolding_Code_Env4_loss)
print("WeightDecay_onlyfor_DeepUnfolding_Code_Env4_acc Accuracies:", WeightDecay_onlyfor_DeepUnfolding_Code_Env4_acc)

#====================================================
# Define the file path
filename = "ScalerwithWeightDecay_onlyfor_DeepUnfolding_Code_Env4s.csv"

# Create empty lists to store the data
iterations = []
ScalerwithWeightDecay_onlyfor_DeepUnfolding_Code_Env4_loss = []
ScalerwithWeightDecay_onlyfor_DeepUnfolding_Code_Env4_acc = []

# Read the CSV file
with open(filename, 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        iterations.append(int(row['Iteration']))
        ScalerwithWeightDecay_onlyfor_DeepUnfolding_Code_Env4_loss.append(float(row['Loss']))
        ScalerwithWeightDecay_onlyfor_DeepUnfolding_Code_Env4_acc.append(float(row['Accuracy']))

# Print the retrieved data
#print("Iterations:", iterations)
print("ScalerwithWeightDecay_onlyfor_DeepUnfolding_Code_Env4 Losses:", ScalerwithWeightDecay_onlyfor_DeepUnfolding_Code_Env4_loss)
print("ScalerwithWeightDecay_onlyfor_DeepUnfolding_Code_Env4 Accuracies:", ScalerwithWeightDecay_onlyfor_DeepUnfolding_Code_Env4_acc)

#====================================================
# Define the file path
filename = "AdaptiveWeightDecay_onlyfor_DeepUnfolding_Code_Env4s.csv"

# Create empty lists to store the data
iterations = []
AdaptiveWeightDecay_onlyfor_DeepUnfolding_Code_Env4s_loss = []
AdaptiveWeightDecay_onlyfor_DeepUnfolding_Code_Env4s_acc = []

# Read the CSV file
with open(filename, 'r') as file:
    reader = csv.DictReader(file)
    for row in reader:
        iterations.append(int(row['Iteration']))
        AdaptiveWeightDecay_onlyfor_DeepUnfolding_Code_Env4s_loss.append(float(row['Loss']))
        AdaptiveWeightDecay_onlyfor_DeepUnfolding_Code_Env4s_acc.append(float(row['Accuracy']))

# Print the retrieved data
#print("Iterations:", iterations)
print("AdaptiveWeightDecay_onlyfor_DeepUnfolding_Code_Env4s Losses:", AdaptiveWeightDecay_onlyfor_DeepUnfolding_Code_Env4s_loss)
print("AdaptiveWeightDecay_onlyfor_DeepUnfolding_Code_Env4s Accuracies:", AdaptiveWeightDecay_onlyfor_DeepUnfolding_Code_Env4s_acc)

plt.figure(figsize=(6, 4))
plt.plot(AdaptiveWeightDecay_onlyfor_DeepUnfolding_Code_Env4s_loss, linewidth=1, marker="+", markersize=5,color='yellow', label="AdaptiveWeightDecay_OnlyDU")
plt.plot(ScalerwithWeightDecay_onlyfor_DeepUnfolding_Code_Env4_loss, linewidth=1, marker="+", markersize=5,color='pink', label="OnlyUnfoldingWeightDecay_SGD_Scaler")
#plt.plot(WeightDecay_onlyfor_DeepUnfolding_Code_Env4_loss, linewidth=1, marker="*", markersize=5,color='black', label="OnlyUnfoldingWeightDecay_SGD")
#plt.plot(FLAdamwithWeightDecay_DeepUnfolding_Code_Env4_loss, linewidth=1, marker="o", markersize=5,color='red', label="FLAdamwithWeightDecay")
#plt.plot(FLSGDwithWeightDecay_DeepUnfolding_Code_Env4_loss, linewidth=1, marker="^", markersize=5,color='brown', label="FLSGDwithWeightDecay")
plt.plot(Default_DUW_loss, linewidth=1, marker="o", markersize=5,color='orange', label="DUW")
plt.plot(Default_FedAvgloss, linewidth=1, marker="+", markersize=5,color='blue', label="FedAvg")
plt.plot(DR_loss, linewidth=1, marker="x", markersize=5,color='green', label="DR")
#plt.plot(originalFedAvgloss, linewidth=3, marker="+", markersize=12,color='red', label="FedAvg")
plt.legend(fontsize=10)
plt.xlabel("com_round t", fontsize=10)
plt.ylabel("loss", fontsize=10)
plt.tick_params(labelsize=10)
plt.tight_layout()
plt.savefig("Propsed_loss.png")

#%%
plt.figure(figsize=(6, 4))
plt.plot(AdaptiveWeightDecay_onlyfor_DeepUnfolding_Code_Env4s_acc, linewidth=1, marker="+", markersize=5,color='yellow', label="AdaptiveWeightDecay_OnlyDU")
#plt.plot(ScalerwithWeightDecay_onlyfor_DeepUnfolding_Code_Env4_acc, linewidth=1, marker="+", markersize=5,color='pink', label="OnlyUnfoldingWeightDecay_SGD_Scaler")
#plt.plot(WeightDecay_onlyfor_DeepUnfolding_Code_Env4_acc, linewidth=1, marker="*", markersize=5,color='black', label="OnlyUnfoldingWeightDecay_SGD")
#plt.plot(FLAdamwithWeightDecay_DeepUnfolding_Code_Env4_acc, linewidth=1, marker="o", markersize=5,color='red', label="FLAdamwithWeightDecay")
#plt.plot(FLSGDwithWeightDecay_DeepUnfolding_Code_Env4_acc, linewidth=1, marker="^", markersize=5,color='brown', label="FLSGDwithWeightDecay")
plt.plot(Default_DUW_acc, linewidth=1, marker="o", markersize=5,color='orange', label="DUW")
plt.plot(Default_FedAvgacc, linewidth=1, marker="+", markersize=5,color='blue', label="FedAvg")
plt.plot(DR_acc, linewidth=1, marker="x", markersize=12,color='green', label="DR")
#plt.plot(originalFedAvgacc, linewidth=3, marker="+", markersize=12,color='red', label="FedAvg")
plt.legend(fontsize=10)
plt.xlabel("com_round t", fontsize=10)
plt.ylabel("accuracy", fontsize=10)
plt.tick_params(labelsize=10)
plt.tight_layout()
plt.savefig("Proposed_acc.png")
# Out:
# FedAvgloss Losses: [158.70630192756653, 152.5932594537735, 142.41599116325378, 130.65969116687774, 119.82372641563416, 103.45049529075622, 86.4729441523552, 74.87950168848037, 65.88165060281753, 58.75102387666702]
# FedAvgacc Accuracies: [0.3016, 0.3958, 0.4444, 0.5053, 0.5453, 0.6719, 0.7372, 0.7685, 0.7863, 0.8006]
# DR_loss Losses: [158.55774598121644, 152.04644536972046, 143.67524075508118, 129.4592413663864, 113.71988971233368, 100.73840839862824, 83.75666259527206, 69.52886077165604, 59.79445659518242, 51.522075933218005]
# DR_acc Accuracies: [0.2699, 0.3936, 0.5576, 0.6521, 0.6875, 0.7162, 0.777, 0.7929, 0.8204, 0.8352]
# Default_DUW_loss Losses: [158.57762808799743, 151.70443580150604, 141.9048832654953, 124.89783456325532, 106.44096329212189, 91.10613074302674, 73.02823816537857, 60.864245533943176, 52.50255209207535, 45.944550710916516]
# Default_DUW_acc Accuracies: [0.2778, 0.4246, 0.5765, 0.6653, 0.7077, 0.7507, 0.8017, 0.8112, 0.8256, 0.8434]
# ...
